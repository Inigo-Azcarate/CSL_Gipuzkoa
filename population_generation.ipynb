# %%
import numpy as np
import pandas as pd
import os
import glob
import matplotlib.pyplot as plt
import statistics
import seaborn as sns
from pathlib import Path
import re
import requests
from io import StringIO
import random
import pdb

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Upload trips data
trips = pd.read_csv('/content/drive/MyDrive/Code/Results/trips2.csv',index_col=0)
trips
# Out:
#        Prov_Ori  Prov_Des                                Com_Ori  \
# 0            20        20                           Donostialdea
# 1            20        20                           Donostialdea
# 2            20        20                           Donostialdea
# 3            20        20                           Donostialdea
# 4            20        20                             Debagoiena
# ...         ...       ...                                    ...
# 21899        20        20                           Donostialdea
# 21900        20        20  Goierri
# 21901        20        20  Goierri
# 21902        20        20  Goierri
# 21903        20        20  Goierri
#
#                                      Com_Des                 Mun_Ori  \
# 0                               Donostialdea  Donostia/San Sebastian
# 1                               Donostialdea  Donostia/San Sebastian
# 2                               Donostialdea  Donostia/San Sebastian
# 3      Goierri                                Donostia/San Sebastian
# 4                               Donostialdea      Arrasate/Mondragon
# ...                                      ...                     ...
# 21899                           Donostialdea                 Hernani
# 21900  Goierri                                             Zumarraga
# 21901  Goierri                                             Zumarraga
# 21902  Goierri                                             Zumarraga
# 21903  Goierri                                             Zumarraga
#
#                       Mun_Des                       Act_Ori  \
# 0      Donostia/San Sebastian                 Otra vivienda
# 1      Donostia/San Sebastian               Centro estudios
# 2      Donostia/San Sebastian  Compras doméstico-familiares
# 3                     Beasain               Asuntos trabajo
# 4      Donostia/San Sebastian               Asuntos trabajo
# ...                       ...                           ...
# 21899                 Hernani          Gestiones personales
# 21900               Zumarraga           Residencia Habitual
# 21901               Zumarraga              Trabajo habitual
# 21902               Zumarraga           Residencia Habitual
# 21903               Zumarraga  Compras doméstico-familiares
#
#                             Act_Des             Proposito             Modo  \
# 0                   Centro estudios                 Otros   Autobús urbano
# 1      Compras doméstico-familiares               Estudio          Andando
# 2                     Otra vivienda               Compras          Andando
# 3                   Asuntos trabajo               Trabajo  Coche conductor
# 4                   Asuntos trabajo               Trabajo  Coche conductor
# ...                             ...                   ...              ...
# 21899           Residencia Habitual  Gestiones Personales  Coche conductor
# 21900              Trabajo habitual               Trabajo  Coche conductor
# 21901           Residencia Habitual               Trabajo  Coche conductor
# 21902            Compras personales               Compras          Andando
# 21903           Residencia Habitual               Compras          Andando
#
#        ... Motos           Tipo_familia  Sexo  Edad  Actividad  crnt_tur  \
# 0      ...     1  2 adultos con niño(s)     2     2          4         2
# 1      ...     1  2 adultos con niño(s)     2     2          4         2
# 2      ...     1  2 adultos con niño(s)     2     2          4         2
# 3      ...     1  2 adultos con niño(s)     1     5          1         1
# 4      ...     1  2 adultos con niño(s)     1     5          1         1
# ...    ...   ...                    ...   ...   ...        ...       ...
# 21899  ...     1   Hogar de una persona     1     6          3         1
# 21900  ...     1              2 adultos     1     5          1         1
# 21901  ...     1              2 adultos     1     5          1         1
# 21902  ...     1              2 adultos     2     5          6         2
# 21903  ...     1              2 adultos     2     5          6         2
#
#        crnt_mot  crnt_otr   Año    Income
# 0             2         2  2021      0.00
# 1             2         2  2021      0.00
# 2             2         2  2021      0.00
# 3             2         1  2021  25397.86
# 4             2         2  2021  27611.51
# ...         ...       ...   ...       ...
# 21899         2         2  2011  23841.61
# 21900         2         2  2011  24108.52
# 21901         2         2  2011  25703.71
# 21902         2         2  2011  11982.27
# 21903         2         2  2011  13577.46
#
# [21904 rows x 32 columns]

# %%
# Quedarse con commute de trabajo
trips = trips[(trips['Act_Ori'].isin(['Trabajo habitual', 'Asuntos trabajo'])) | (trips['Act_Des'].isin(['Trabajo habitual', 'Asuntos trabajo']))]
trips = trips.reset_index(drop=True)

# 2021 poblacion actual
trips = trips[trips['Año'] == 2021]
trips
# Out:
#       Prov_Ori  Prov_Des                                Com_Ori  \
# 0           20        20                           Donostialdea
# 1           20        20                             Debagoiena
# 2           20        20                           Donostialdea
# 3           20        20                           Donostialdea
# 4           20        20                           Donostialdea
# ...        ...       ...                                    ...
# 2205        20        20                             Debagoiena
# 2206        20        20  Goierri
# 2207        20        20  Goierri
# 2208        20        20                           Donostialdea
# 2209        20        20                           Donostialdea
#
#                                     Com_Des                 Mun_Ori  \
# 0     Goierri                                Donostia/San Sebastian
# 1                              Donostialdea      Arrasate/Mondragon
# 2                              Donostialdea                 Urnieta
# 3                              Donostialdea                 Urnieta
# 4                        Urola Kosta                        Andoain
# ...                                     ...                     ...
# 2205  Goierri                                               Bergara
# 2206  Goierri                                             Zumarraga
# 2207  Goierri                                             Zumarraga
# 2208                           Donostialdea            Lasarte-Oria
# 2209                           Donostialdea  Donostia/San Sebastian
#
#                      Mun_Des                 Act_Ori                 Act_Des  \
# 0                    Beasain         Asuntos trabajo         Asuntos trabajo
# 1     Donostia/San Sebastian         Asuntos trabajo         Asuntos trabajo
# 2                    Urnieta        Trabajo habitual  Ocio, cultura, deporte
# 3                    Urnieta  Ocio, cultura, deporte        Trabajo habitual
# 4                    Zarautz        Trabajo habitual    Gestiones personales
# ...                      ...                     ...                     ...
# 2205               Zumarraga        Trabajo habitual     Residencia Habitual
# 2206               Zumarraga        Trabajo habitual     Residencia Habitual
# 2207               Zumarraga     Residencia Habitual        Trabajo habitual
# 2208  Donostia/San Sebastian     Residencia Habitual         Asuntos trabajo
# 2209            Lasarte-Oria         Asuntos trabajo     Residencia Habitual
#
#      Proposito             Modo  ... Motos             Tipo_familia  Sexo  \
# 0      Trabajo  Coche conductor  ...     1    2 adultos con niño(s)     1
# 1      Trabajo  Coche conductor  ...     1    2 adultos con niño(s)     1
# 2      Trabajo  Coche conductor  ...     1                2 adultos     1
# 3         Ocio  Coche conductor  ...     1                2 adultos     1
# 4      Trabajo  Coche conductor  ...     1    2 adultos con niño(s)     1
# ...        ...              ...  ...   ...                      ...   ...
# 2205   Trabajo  Coche conductor  ...     1  Otros hogares con niños     2
# 2206   Trabajo          Andando  ...     1  Otros hogares con niños     1
# 2207   Trabajo          Andando  ...     1  Otros hogares con niños     1
# 2208   Trabajo  Coche conductor  ...     1     Hogar de una persona     1
# 2209   Trabajo  Coche conductor  ...     1     Hogar de una persona     1
#
#       Edad  Actividad  crnt_tur  crnt_mot  crnt_otr   Año     Income
# 0        5          1         1         2         1  2021  25397.860
# 1        5          1         1         2         2  2021  27611.510
# 2        5          1         1         1         1  2021  26229.910
# 3        5          1         1         1         1  2021  26229.910
# 4        5          1         1         2         2  2021  25397.860
# ...    ...        ...       ...       ...       ...   ...        ...
# 2205     5          1         1         2         2  2021  23335.260
# 2206     3          1         1         2         2  2021  23819.585
# 2207     3          1         1         2         2  2021  21452.435
# 2208     5          1         1         2         2  2021  26198.010
# 2209     5          1         1         2         2  2021  24602.820
#
# [2210 rows x 32 columns]

# %%
trips['elev'] = trips['elev']/trips['elev'].min()
trips['elev'] = trips['elev'].apply(lambda x: int(x) if isinstance(x, float) else x)

# %%
# Expandir los trips, hacer que cada trayecto sea una fila

# Crear una lista de filas duplicadas
nuevas_filas = []
for index, row in trips.iterrows():
    valores_columnas = row[trips.columns]
    repeticiones = row['elev']
    nuevas_filas.extend([valores_columnas] * repeticiones)

# Crear un nuevo DataFrame con las filas duplicadas
trips = pd.DataFrame(nuevas_filas, columns=trips.columns)

# Elimino la columna desplazamientos que ya no tiene sentido alguno
trips = trips.drop(columns=["elev"])

# Mezclo las filas de manera aleatoria
trips = trips.sample(frac=1).reset_index(drop=True)
trips
# Out:
#        Prov_Ori  Prov_Des                                Com_Ori  \
# 0            20        20                           Donostialdea
# 1            20        20                           Donostialdea
# 2            20        20                     Urola Kosta
# 3            20        20                                Bidasoa
# 4            20        20                           Donostialdea
# ...         ...       ...                                    ...
# 10711        20        20                           Donostialdea
# 10712        20        20                           Donostialdea
# 10713        20        20                           Donostialdea
# 10714        20        20  Goierri
# 10715        20        20                           Donostialdea
#
#                                      Com_Des                 Mun_Ori  \
# 0                               Donostialdea  Donostia/San Sebastian
# 1                               Donostialdea  Donostia/San Sebastian
# 2                         Urola Kosta                           Orio
# 3                         Urola Kosta                           Irun
# 4                               Donostialdea  Donostia/San Sebastian
# ...                                      ...                     ...
# 10711                           Donostialdea  Donostia/San Sebastian
# 10712                                Bidasoa  Donostia/San Sebastian
# 10713                           Donostialdea  Donostia/San Sebastian
# 10714  Goierri                                               Urretxu
# 10715                                Bidasoa                 Usurbil
#
#                       Mun_Des                           Act_Ori  \
# 0      Donostia/San Sebastian                  Trabajo habitual
# 1      Donostia/San Sebastian                  Trabajo habitual
# 2                     Zarautz               Residencia Habitual
# 3                     Zarautz               Residencia Habitual
# 4      Donostia/San Sebastian               Residencia Habitual
# ...                       ...                               ...
# 10711                Oiartzun               Residencia Habitual
# 10712             Hondarribia                  Trabajo habitual
# 10713  Donostia/San Sebastian  Acompañamiento de ayuda, cuidado
# 10714                 Urretxu               Residencia Habitual
# 10715                    Irun                  Trabajo habitual
#
#                                 Act_Des             Proposito  \
# 0      Acompañamiento de ayuda, cuidado               Trabajo
# 1                   Residencia Habitual               Trabajo
# 2                      Trabajo habitual               Trabajo
# 3                      Trabajo habitual               Trabajo
# 4                      Trabajo habitual               Trabajo
# ...                                 ...                   ...
# 10711                  Trabajo habitual               Trabajo
# 10712               Residencia Habitual               Trabajo
# 10713                  Trabajo habitual  Gestiones Personales
# 10714                  Trabajo habitual               Trabajo
# 10715               Residencia Habitual               Trabajo
#
#                   Modo  ... Motos             Tipo_familia  Sexo  Edad  \
# 0      Coche conductor  ...     2  Otros hogares sin niños     2     4
# 1      Coche conductor  ...     1                2 adultos     2     5
# 2      Coche conductor  ...     2                2 adultos     2     5
# 3      Coche conductor  ...     1     Hogar de una persona     1     4
# 4      Coche conductor  ...     1    2 adultos con niño(s)     1     5
# ...                ...  ...   ...                      ...   ...   ...
# 10711  Coche conductor  ...     2  Otros hogares sin niños     2     5
# 10712   Coche pasajero  ...     1  Otros hogares sin niños     1     4
# 10713  Coche conductor  ...     2    2 adultos con niño(s)     1     4
# 10714          Andando  ...     1    2 adultos con niño(s)     1     5
# 10715  Coche conductor  ...     1    2 adultos con niño(s)     1     5
#
#        Actividad  crnt_tur  crnt_mot crnt_otr   Año    Income
# 0              1         1         2        2  2021  26401.96
# 1              1         1         2        2  2021  27299.26
# 2              1         1         2        2  2021  24662.51
# 3              1         1         2        2  2021  23263.22
# 4              1         1         2        2  2021  28185.41
# ...          ...       ...       ...      ...   ...       ...
# 10711          1         1         2        2  2021  26892.91
# 10712          1         2         2        2  2021  24992.16
# 10713          1         1         1        2  2021  26958.71
# 10714          1         1         2        2  2021  25500.46
# 10715          1         1         2        1  2021  25097.96
#
# [10716 rows x 31 columns]

# %%
trips = trips[trips['Mun_Ori'] != trips['Mun_Des']]
# trips = trips[(trips['Com_Ori'] == 'Donostialdea') | (trips['Com_Des'] == 'Donostialdea')]
trips = trips[trips['Com_Des'] == 'Donostialdea']
trips = trips[trips['Income'] > 1] # Quito a los estudiantes que hacen trips de trabajo
trips
# Out:
#        Prov_Ori  Prov_Des                                Com_Ori  \
# 19           20        20                           Donostialdea
# 23           20        20                     Urola Kosta
# 26           20        20                           Donostialdea
# 46           20        20                             Debagoiena
# 50           20        20                           Donostialdea
# ...         ...       ...                                    ...
# 10701        20        20                                Bidasoa
# 10704        20        20  Goierri
# 10705        20        20                                Bidasoa
# 10708        20        20                           Donostialdea
# 10711        20        20                           Donostialdea
#
#             Com_Des                 Mun_Ori                 Mun_Des  \
# 19     Donostialdea                Oiartzun              Errenteria
# 23     Donostialdea                    Orio                 Andoain
# 26     Donostialdea  Donostia/San Sebastian                 Hernani
# 46     Donostialdea                 Bergara                 Usurbil
# 50     Donostialdea  Donostia/San Sebastian                 Urnieta
# ...             ...                     ...                     ...
# 10701  Donostialdea                    Irun                Oiartzun
# 10704  Donostialdea                 Legazpi  Donostia/San Sebastian
# 10705  Donostialdea                    Irun  Donostia/San Sebastian
# 10708  Donostialdea  Donostia/San Sebastian                  Pasaia
# 10711  Donostialdea  Donostia/San Sebastian                Oiartzun
#
#                    Act_Ori              Act_Des Proposito             Modo  \
# 19     Residencia Habitual     Trabajo habitual   Trabajo  Coche conductor
# 23     Residencia Habitual     Trabajo habitual   Trabajo  Coche conductor
# 26        Trabajo habitual  Residencia Habitual   Trabajo  Coche conductor
# 46        Trabajo habitual  Residencia Habitual   Trabajo  Coche conductor
# 50        Trabajo habitual  Residencia Habitual   Trabajo  Coche conductor
# ...                    ...                  ...       ...              ...
# 10701     Trabajo habitual  Residencia Habitual   Trabajo  Coche conductor
# 10704  Residencia Habitual      Asuntos trabajo   Trabajo  Coche conductor
# 10705  Residencia Habitual     Trabajo habitual   Trabajo  Coche conductor
# 10708  Residencia Habitual     Trabajo habitual   Trabajo          Andando
# 10711  Residencia Habitual     Trabajo habitual   Trabajo  Coche conductor
#
#        ... Motos             Tipo_familia  Sexo  Edad  Actividad  crnt_tur  \
# 19     ...     2  Otros hogares con niños     2     3          1         1
# 23     ...     1     Hogar de una persona     1     4          1         1
# 26     ...     1     Hogar de una persona     2     5          1         1
# 46     ...     1  Otros hogares sin niños     2     4          1         1
# 50     ...     1  Otros hogares sin niños     1     5          1         1
# ...    ...   ...                      ...   ...   ...        ...       ...
# 10701  ...     1    2 adultos con niño(s)     1     5          1         1
# 10704  ...     1     Hogar de una persona     1     5          1         1
# 10705  ...     1    2 adultos con niño(s)     1     6          1         1
# 10708  ...     1    2 adultos con niño(s)     2     5          1         1
# 10711  ...     2  Otros hogares sin niños     2     5          1         1
#
#        crnt_mot crnt_otr   Año     Income
# 19            2        2  2021  23763.435
# 23            2        2  2021  25309.110
# 26            2        2  2021  22911.920
# 46            2        2  2021  25997.260
# 50            2        2  2021  28048.410
# ...         ...      ...   ...        ...
# 10701         1        2  2021  25461.260
# 10704         2        2  2021  23463.100
# 10705         2        2  2021  24718.410
# 10708         2        2  2021  22504.870
# 10711         2        2  2021  26892.910
#
# [2462 rows x 31 columns]

# %% [markdown]
# # Asigno LAT Y LONG Origen y Destino

# %%
import geopandas as gpd
# Leer el archivo Shapefile
gdf = gpd.read_file('/content/drive/MyDrive/Code/Data/ERAIKINAK_EDIFICIOS/buildings.shp')

# Pasar las geometrias de los edificios de sistema UTM a sistema decimal de coordenadas
crs_objetivo = 'EPSG:4326'  # WGS84
gdf = gdf.to_crs(crs_objetivo)

# Crear una columna que contiene el centroide del edificio, para obtener un punto
gdf['Centroide'] = gdf['geometry'].centroid
gdf.columns
# Out:
# <ipython-input-8-42cfb7b7801c>:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   gdf['Centroide'] = gdf['geometry'].centroid
# Index(['Town', 'Edificabil', 'Solar', 'Vivienda', 'Trastero', 'Garaje Cer',
#        'Agropecuar', 'Local Come', 'Industrial', 'Almacen', 'Deportivo',
#        'Cultural', 'Educativo', 'Oficina', 'Hosteleria', 'Obras Urba',
#        'Altura men', 'Terraza', 'Accesos y', 'Jardin', 'Sanidad', 'Deposito',
#        'Duplex', 'Plaza Park', 'Religioso', 'Espectacul', 'geometry',
#        'Centroide'],
#       dtype='object')

# %%
asignaciones = {
    'Otra vivienda': ['Vivienda', 'Duplex'],
    'Centro estudios': ['Educativo'],
    'Compras doméstico-familiares': ['Local Come'],
    'Asuntos trabajo': ['Oficina'],
    'Trabajo habitual': ['Oficina'],
    'Ocio, cultura, deporte': ['Deportivo', 'Cultural', 'Hosteleria', 'Terraza', 'Jardin', 'Religioso', 'Espectacul'],
    'Acompañamiento de ayuda, cuidado': ['Local Come'],
    'Residencia Habitual': ['Vivienda', 'Duplex'],
    'Médico / Hospital': ['Sanidad'],
    'Gestiones personales': ['Local Come'],
    'Compras personales': ['Local Come'],
    'Otras actividades': ['Local Come'],
    'Gestiones doméstico-familiares': ['Local Come'],

}

# Encontrar la longitud máxima de todas las listas
max_length = max(len(lista) for lista in asignaciones.values())

# Rellenar las listas con valores NaN para que tengan la misma longitud
for columna in asignaciones:
    asignaciones[columna] += [np.nan] * (max_length - len(asignaciones[columna]))

# Crear el DataFrame a partir del diccionario
asignaciones = pd.DataFrame(asignaciones)

# %%
# Función para obtener la lista de una columna específica
def obtener_lista_por_columna(df, columna):
    if columna in df.columns:
        l = df[columna].tolist()
        l = [x for x in l if isinstance(x, str)]
        return l
    else:
        return []

# Función para asignar coord_origen basado en la probabilidad de vivienda
def asignar_coord_origen(row):
    matching_rows = gdf[gdf['Town'] == row['Mun_Ori']] # Lista con todos las RC de ese pueblo
    matching_usos = obtener_lista_por_columna(asignaciones, row['Act_Ori']) # Lista con los posibles usos de esa actividad
    matching_rows = matching_rows[(matching_rows[matching_usos] != 0).any(axis=1)] # De las RC del pueblo, coge solo las que no tienen nulo el m2, mínimo alguno de los usos de suelo asignado a esa actividad origen. Esto es, si hay alguna RC que no tiene ningún uso de suelo de interés para esa actividad, se elimina.

    # Genero una matriz auxiliar quitando Town, geometry y Centroide para hacer los calculos
    auxiliar = matching_rows.drop(columns=['Town', 'geometry', 'Centroide'])
    # Hasta este punto, tengo un gdf con las RC de pueblo adecuado y con todas las RC que hacen match con esa actividad, esto es, no hay ninguna fila que tenga todos los m2 nulos.
    # El próximo paso es asignar una fila (RC), y para ello escojo por probabilidad una ubicación exacta de la matriz (tanto RC como uso de suelo) y selecciono esa fila (RC) para pasarle

    if not matching_rows.empty:
        probabilidades = auxiliar.values / auxiliar.values.sum() # Normalizar los valores para representar probabilidades
        # Generar números aleatorios para seleccionar fila y columna
        fila_seleccionada = random.choices(range(auxiliar.shape[0]), weights=probabilidades.sum(axis=1))[0]
        columna_seleccionada = random.choices(range(auxiliar.shape[1]), weights=probabilidades[fila_seleccionada])[0]
        valor_seleccionado = auxiliar.iloc[fila_seleccionada, columna_seleccionada]         # Obtener el valor seleccionado, fila y columna
        fila = matching_rows.index[fila_seleccionada] # Devolver la fila, la columna y el valor seleccionado
        return gdf.loc[fila, 'Centroide']
    else:
        return None

trips['Edif_Ori'] = trips.apply(asignar_coord_origen, axis=1)

# %%
# Pasa de un punto en formato WKT a dos columnas con LONG y LAT

from shapely import wkt
from shapely.geometry import Point

def extraer_longitud(punto):
    return punto.x

def extraer_latitud(punto):
    return punto.y

# from shapely import wkt
# from shapely.geometry import Point

# def extraer_longitud(punto_wkt):
#     punto = wkt.loads(punto_wkt)
#     return punto.x

# def extraer_latitud(punto_wkt):
#     punto = wkt.loads(punto_wkt)
#     return punto.y

trips['O_long'] = trips['Edif_Ori'].apply(extraer_longitud)
trips['O_lat'] = trips['Edif_Ori'].apply(extraer_latitud)


# Eliminar columnas innecesarias

trips = trips.drop(columns=["Edif_Ori"])
trips = trips.reset_index(drop=True)
trips
# Out:
#       Prov_Ori  Prov_Des                                Com_Ori       Com_Des  \
# 0           20        20                           Donostialdea  Donostialdea
# 1           20        20                     Urola Kosta         Donostialdea
# 2           20        20                           Donostialdea  Donostialdea
# 3           20        20                             Debagoiena  Donostialdea
# 4           20        20                           Donostialdea  Donostialdea
# ...        ...       ...                                    ...           ...
# 2457        20        20                                Bidasoa  Donostialdea
# 2458        20        20  Goierri                                Donostialdea
# 2459        20        20                                Bidasoa  Donostialdea
# 2460        20        20                           Donostialdea  Donostialdea
# 2461        20        20                           Donostialdea  Donostialdea
#
#                      Mun_Ori                 Mun_Des              Act_Ori  \
# 0                   Oiartzun              Errenteria  Residencia Habitual
# 1                       Orio                 Andoain  Residencia Habitual
# 2     Donostia/San Sebastian                 Hernani     Trabajo habitual
# 3                    Bergara                 Usurbil     Trabajo habitual
# 4     Donostia/San Sebastian                 Urnieta     Trabajo habitual
# ...                      ...                     ...                  ...
# 2457                    Irun                Oiartzun     Trabajo habitual
# 2458                 Legazpi  Donostia/San Sebastian  Residencia Habitual
# 2459                    Irun  Donostia/San Sebastian  Residencia Habitual
# 2460  Donostia/San Sebastian                  Pasaia  Residencia Habitual
# 2461  Donostia/San Sebastian                Oiartzun  Residencia Habitual
#
#                   Act_Des Proposito             Modo  ... Sexo  Edad  \
# 0        Trabajo habitual   Trabajo  Coche conductor  ...    2     3
# 1        Trabajo habitual   Trabajo  Coche conductor  ...    1     4
# 2     Residencia Habitual   Trabajo  Coche conductor  ...    2     5
# 3     Residencia Habitual   Trabajo  Coche conductor  ...    2     4
# 4     Residencia Habitual   Trabajo  Coche conductor  ...    1     5
# ...                   ...       ...              ...  ...  ...   ...
# 2457  Residencia Habitual   Trabajo  Coche conductor  ...    1     5
# 2458      Asuntos trabajo   Trabajo  Coche conductor  ...    1     5
# 2459     Trabajo habitual   Trabajo  Coche conductor  ...    1     6
# 2460     Trabajo habitual   Trabajo          Andando  ...    2     5
# 2461     Trabajo habitual   Trabajo  Coche conductor  ...    2     5
#
#       Actividad  crnt_tur  crnt_mot  crnt_otr   Año     Income    O_long  \
# 0             1         1         2         2  2021  23763.435 -1.869476
# 1             1         1         2         2  2021  25309.110 -2.128351
# 2             1         1         2         2  2021  22911.920 -1.977797
# 3             1         1         2         2  2021  25997.260 -2.423608
# 4             1         1         2         2  2021  28048.410 -2.019292
# ...         ...       ...       ...       ...   ...        ...       ...
# 2457          1         1         1         2  2021  25461.260 -1.761189
# 2458          1         1         2         2  2021  23463.100 -2.341281
# 2459          1         1         2         2  2021  24718.410 -1.798813
# 2460          1         1         2         2  2021  22504.870 -2.003906
# 2461          1         1         2         2  2021  26892.910 -1.944472
#
#           O_lat
# 0     43.299272
# 1     43.276954
# 2     43.303195
# 3     43.104149
# 4     43.306946
# ...         ...
# 2457  43.339585
# 2458  43.059045
# 2459  43.343189
# 2460  43.311991
# 2461  43.320328
#
# [2462 rows x 33 columns]

# %%
trips['D_long'] = -2.033693
trips['D_lat'] = 43.256347

# %%
trips.columns
# Out:
# Index(['Prov_Ori', 'Prov_Des', 'Com_Ori', 'Com_Des', 'Mun_Ori', 'Mun_Des',
#        'Act_Ori', 'Act_Des', 'Proposito', 'Modo', 'Hora_Ini', 'Dur_Tot',
#        'Recur', 'Bill', 'Park', 'Peaje', 'Provincia', 'Municipio', 'Comarca',
#        'Per_hog', 'Turismos', 'Motos', 'Tipo_familia', 'Sexo', 'Edad',
#        'Actividad', 'crnt_tur', 'crnt_mot', 'crnt_otr', 'Año', 'Income',
#        'O_long', 'O_lat', 'D_long', 'D_lat'],
#       dtype='object')

# %%
# Me quedo con las filas que sirven para entrenar el modelo

eliminar = ['Prov_Ori', 'Prov_Des',
       'Act_Ori', 'Act_Des', 'Proposito', 'Dur_Tot',
       'Bill', 'Park', 'Peaje', 'Provincia','Comarca',
       'crnt_mot', 'crnt_otr']
trips = trips.drop(columns=eliminar)
trips
# Out:
#                                     Com_Ori       Com_Des  \
# 0                              Donostialdea  Donostialdea
# 1                        Urola Kosta         Donostialdea
# 2                              Donostialdea  Donostialdea
# 3                                Debagoiena  Donostialdea
# 4                              Donostialdea  Donostialdea
# ...                                     ...           ...
# 2457                                Bidasoa  Donostialdea
# 2458  Goierri                                Donostialdea
# 2459                                Bidasoa  Donostialdea
# 2460                           Donostialdea  Donostialdea
# 2461                           Donostialdea  Donostialdea
#
#                      Mun_Ori                 Mun_Des             Modo  \
# 0                   Oiartzun              Errenteria  Coche conductor
# 1                       Orio                 Andoain  Coche conductor
# 2     Donostia/San Sebastian                 Hernani  Coche conductor
# 3                    Bergara                 Usurbil  Coche conductor
# 4     Donostia/San Sebastian                 Urnieta  Coche conductor
# ...                      ...                     ...              ...
# 2457                    Irun                Oiartzun  Coche conductor
# 2458                 Legazpi  Donostia/San Sebastian  Coche conductor
# 2459                    Irun  Donostia/San Sebastian  Coche conductor
# 2460  Donostia/San Sebastian                  Pasaia          Andando
# 2461  Donostia/San Sebastian                Oiartzun  Coche conductor
#
#      Hora_Ini  Recur               Municipio  Per_hog  Turismos  ...  Sexo  \
# 0       14:50     22                Oiartzun        2         3  ...     2
# 1       20:40     22                    Orio        1         2  ...     1
# 2       20:00     22                 Hernani        1         2  ...     2
# 3       15:00     22                 Usurbil        2         4  ...     2
# 4       14:00     23                 Urnieta        2         2  ...     1
# ...       ...    ...                     ...      ...       ...  ...   ...
# 2457    13:00     22                Oiartzun        2         3  ...     1
# 2458    08:00     99                 Legazpi        1         2  ...     1
# 2459    05:05     22                    Irun        2         2  ...     1
# 2460    20:30     23  Donostia/San Sebastian        2         2  ...     2
# 2461    07:15     22  Donostia/San Sebastian        2         3  ...     2
#
#      Edad  Actividad  crnt_tur   Año     Income    O_long      O_lat  \
# 0       3          1         1  2021  23763.435 -1.869476  43.299272
# 1       4          1         1  2021  25309.110 -2.128351  43.276954
# 2       5          1         1  2021  22911.920 -1.977797  43.303195
# 3       4          1         1  2021  25997.260 -2.423608  43.104149
# 4       5          1         1  2021  28048.410 -2.019292  43.306946
# ...   ...        ...       ...   ...        ...       ...        ...
# 2457    5          1         1  2021  25461.260 -1.761189  43.339585
# 2458    5          1         1  2021  23463.100 -2.341281  43.059045
# 2459    6          1         1  2021  24718.410 -1.798813  43.343189
# 2460    5          1         1  2021  22504.870 -2.003906  43.311991
# 2461    5          1         1  2021  26892.910 -1.944472  43.320328
#
#         D_long      D_lat
# 0    -2.033693  43.256347
# 1    -2.033693  43.256347
# 2    -2.033693  43.256347
# 3    -2.033693  43.256347
# 4    -2.033693  43.256347
# ...        ...        ...
# 2457 -2.033693  43.256347
# 2458 -2.033693  43.256347
# 2459 -2.033693  43.256347
# 2460 -2.033693  43.256347
# 2461 -2.033693  43.256347
#
# [2462 rows x 22 columns]

# %%
trips.to_csv('/content/drive/MyDrive/Code/Results/workers_eskuzaitzeta.csv')
