# %% [markdown]
# # Import libraries and mount drive

# %%
import numpy as np
#import pandas as pd
import os
import glob
#import matplotlib.pyplot as plt
import statistics
import seaborn as sns
from pathlib import Path
import re
import requests
from io import StringIO
import random
import pdb

import matplotlib
matplotlib.use('agg')  # allows notebook to be tested in Travis

import pandas as pd
#import cartopy.crs as ccrs
#import cartopy
import matplotlib.pyplot as plt
#import pandana as pdna
import time

# !pip install pandana
import pandana as pdna

# !pip install cartopy
# import cartopy.crs as ccrs
# import cartopy

# !pip install urbanaccess
import urbanaccess as ua
from urbanaccess.config import settings
from urbanaccess.gtfsfeeds import feeds
from urbanaccess import gtfsfeeds
from urbanaccess.gtfs.gtfsfeeds_dataframe import gtfsfeeds_dfs
from urbanaccess.network import ua_network, load_network

# %matplotlib inline
# Out:
# Requirement already satisfied: pandana in /usr/local/lib/python3.10/dist-packages (0.7)
# Requirement already satisfied: numpy>=1.8 in /usr/local/lib/python3.10/dist-packages (from pandana) (1.23.5)
# Requirement already satisfied: pandas>=0.17 in /usr/local/lib/python3.10/dist-packages (from pandana) (1.5.3)
# Requirement already satisfied: requests>=2.0 in /usr/local/lib/python3.10/dist-packages (from pandana) (2.31.0)
# Requirement already satisfied: scikit-learn>=0.18 in /usr/local/lib/python3.10/dist-packages (from pandana) (1.2.2)
# Requirement already satisfied: tables>=3.1 in /usr/local/lib/python3.10/dist-packages (from pandana) (3.8.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.17->pandana) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.17->pandana) (2023.3.post1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.0->pandana) (3.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.0->pandana) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.0->pandana) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.0->pandana) (2023.7.22)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.18->pandana) (1.11.3)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.18->pandana) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.18->pandana) (3.2.0)
# Requirement already satisfied: cython>=0.29.21 in /usr/local/lib/python3.10/dist-packages (from tables>=3.1->pandana) (3.0.4)
# Requirement already satisfied: numexpr>=2.6.2 in /usr/local/lib/python3.10/dist-packages (from tables>=3.1->pandana) (2.8.7)
# Requirement already satisfied: blosc2~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from tables>=3.1->pandana) (2.0.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tables>=3.1->pandana) (23.2)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.10/dist-packages (from tables>=3.1->pandana) (9.0.0)
# Requirement already satisfied: msgpack in /usr/local/lib/python3.10/dist-packages (from blosc2~=2.0.0->tables>=3.1->pandana) (1.0.7)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=0.17->pandana) (1.16.0)
# Requirement already satisfied: urbanaccess in /usr/local/lib/python3.10/dist-packages (0.2.2)
# Requirement already satisfied: requests>=2.9.1 in /usr/local/lib/python3.10/dist-packages (from urbanaccess) (2.31.0)
# Requirement already satisfied: six>=1.11 in /usr/local/lib/python3.10/dist-packages (from urbanaccess) (1.16.0)
# Requirement already satisfied: pandas>=0.17.0 in /usr/local/lib/python3.10/dist-packages (from urbanaccess) (1.5.3)
# Requirement already satisfied: numpy>=1.11 in /usr/local/lib/python3.10/dist-packages (from urbanaccess) (1.23.5)
# Requirement already satisfied: osmnet>=0.1.4 in /usr/local/lib/python3.10/dist-packages (from urbanaccess) (0.1.7)
# Requirement already satisfied: pandana>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from urbanaccess) (0.7)
# Requirement already satisfied: matplotlib>=2.0 in /usr/local/lib/python3.10/dist-packages (from urbanaccess) (3.7.1)
# Requirement already satisfied: geopy>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from urbanaccess) (2.3.0)
# Requirement already satisfied: pyyaml>=3.11 in /usr/local/lib/python3.10/dist-packages (from urbanaccess) (6.0.1)
# Requirement already satisfied: scikit-learn>=0.17.1 in /usr/local/lib/python3.10/dist-packages (from urbanaccess) (1.2.2)
# Requirement already satisfied: geographiclib<3,>=1.52 in /usr/local/lib/python3.10/dist-packages (from geopy>=1.11.0->urbanaccess) (2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0->urbanaccess) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0->urbanaccess) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0->urbanaccess) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0->urbanaccess) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0->urbanaccess) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0->urbanaccess) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0->urbanaccess) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0->urbanaccess) (2.8.2)
# Requirement already satisfied: geopandas>=0.11 in /usr/local/lib/python3.10/dist-packages (from osmnet>=0.1.4->urbanaccess) (0.13.2)
# Requirement already satisfied: shapely>=1.8 in /usr/local/lib/python3.10/dist-packages (from osmnet>=0.1.4->urbanaccess) (2.0.2)
# Requirement already satisfied: tables>=3.1 in /usr/local/lib/python3.10/dist-packages (from pandana>=0.2.0->urbanaccess) (3.8.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.17.0->urbanaccess) (2023.3.post1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.9.1->urbanaccess) (3.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.9.1->urbanaccess) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.9.1->urbanaccess) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.9.1->urbanaccess) (2023.7.22)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.17.1->urbanaccess) (1.11.3)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.17.1->urbanaccess) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.17.1->urbanaccess) (3.2.0)
# Requirement already satisfied: fiona>=1.8.19 in /usr/local/lib/python3.10/dist-packages (from geopandas>=0.11->osmnet>=0.1.4->urbanaccess) (1.9.5)
# Requirement already satisfied: pyproj>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from geopandas>=0.11->osmnet>=0.1.4->urbanaccess) (3.6.1)
# Requirement already satisfied: cython>=0.29.21 in /usr/local/lib/python3.10/dist-packages (from tables>=3.1->pandana>=0.2.0->urbanaccess) (3.0.4)
# Requirement already satisfied: numexpr>=2.6.2 in /usr/local/lib/python3.10/dist-packages (from tables>=3.1->pandana>=0.2.0->urbanaccess) (2.8.7)
# Requirement already satisfied: blosc2~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from tables>=3.1->pandana>=0.2.0->urbanaccess) (2.0.0)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.10/dist-packages (from tables>=3.1->pandana>=0.2.0->urbanaccess) (9.0.0)
# Requirement already satisfied: msgpack in /usr/local/lib/python3.10/dist-packages (from blosc2~=2.0.0->tables>=3.1->pandana>=0.2.0->urbanaccess) (1.0.7)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas>=0.11->osmnet>=0.1.4->urbanaccess) (23.1.0)
# Requirement already satisfied: click~=8.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas>=0.11->osmnet>=0.1.4->urbanaccess) (8.1.7)
# Requirement already satisfied: click-plugins>=1.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas>=0.11->osmnet>=0.1.4->urbanaccess) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas>=0.11->osmnet>=0.1.4->urbanaccess) (0.7.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas>=0.11->osmnet>=0.1.4->urbanaccess) (67.7.2)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Load data to an Urban Access transit data object

# %%
# I manually add all the feeds from the bus transit companies of Gipuzkoa

feeds.add_feed(add_dict={'dbus': 'https://www.geo.euskadi.eus/cartografia/DatosDescarga/Transporte/Moveuskadi/ATTG/dbus/google_transit.zip'})
feeds.add_feed(add_dict={'lurraldebus_areizaga': 'https://www.geo.euskadi.eus/cartografia/DatosDescarga/Transporte/Moveuskadi/ATTG/lurraldebus_areizaga/google_transit.zip'})
feeds.add_feed(add_dict={'lurraldebus_arrasate': 'https://www.geo.euskadi.eus/cartografia/DatosDescarga/Transporte/Moveuskadi/ATTG/lurraldebus_arrasate/google_transit.zip'})
feeds.add_feed(add_dict={'lurraldebus_auif_urb': 'https://www.geo.euskadi.eus/cartografia/DatosDescarga/Transporte/Moveuskadi/ATTG/lurraldebus_auif_urb/google_transit.zip'})
feeds.add_feed(add_dict={'lurraldebus_eibar': 'https://www.geo.euskadi.eus/cartografia/DatosDescarga/Transporte/Moveuskadi/ATTG/lurraldebus_eibar/google_transit.zip'})
feeds.add_feed(add_dict={'lurraldebus_ekialdebus': 'https://www.geo.euskadi.eus/cartografia/DatosDescarga/Transporte/Moveuskadi/ATTG/lurraldebus_ekialdebus/google_transit.zip'})
feeds.add_feed(add_dict={'lurraldebus_euskotren_bus': 'https://www.geo.euskadi.eus/cartografia/DatosDescarga/Transporte/Moveuskadi/ATTG/lurraldebus_euskotren_bus/google_transit.zip'})
feeds.add_feed(add_dict={'lurraldebus_garayar': 'https://www.geo.euskadi.eus/cartografia/DatosDescarga/Transporte/Moveuskadi/ATTG/lurraldebus_garayar/google_transit.zip'})
feeds.add_feed(add_dict={'lurraldebus_gipuzkoana': 'https://www.geo.euskadi.eus/cartografia/DatosDescarga/Transporte/Moveuskadi/ATTG/lurraldebus_gipuzkoana/google_transit.zip'})
feeds.add_feed(add_dict={'lurraldebus_goierrialdea': 'https://www.geo.euskadi.eus/cartografia/DatosDescarga/Transporte/Moveuskadi/ATTG/lurraldebus_goierrialdea/google_transit.zip'})
feeds.add_feed(add_dict={'lurraldebus_hernani': 'https://www.geo.euskadi.eus/cartografia/DatosDescarga/Transporte/Moveuskadi/ATTG/lurraldebus_hernani/google_transit.zip'})
feeds.add_feed(add_dict={'lurraldebus_lasarte': 'https://www.geo.euskadi.eus/cartografia/DatosDescarga/Transporte/Moveuskadi/ATTG/lurraldebus_lasarte/google_transit.zip'})
feeds.add_feed(add_dict={'lurraldebus_oiartzun': 'https://www.geo.euskadi.eus/cartografia/DatosDescarga/Transporte/Moveuskadi/ATTG/lurraldebus_oiartzun/google_transit.zip'})
feeds.add_feed(add_dict={'lurraldebus_pesa': 'https://www.geo.euskadi.eus/cartografia/DatosDescarga/Transporte/Moveuskadi/ATTG/lurraldebus_pesa/google_transit.zip'})
feeds.add_feed(add_dict={'lurraldebus_renteria': 'https://www.geo.euskadi.eus/cartografia/DatosDescarga/Transporte/Moveuskadi/ATTG/lurraldebus_renteria/google_transit.zip'})
feeds.add_feed(add_dict={'lurraldebus_tbh': 'https://www.geo.euskadi.eus/cartografia/DatosDescarga/Transporte/Moveuskadi/ATTG/lurraldebus_tbh/google_transit.zip'})
feeds.add_feed(add_dict={'lurraldebus_tolosaldea': 'https://www.geo.euskadi.eus/cartografia/DatosDescarga/Transporte/Moveuskadi/ATTG/lurraldebus_tolosaldea/google_transit.zip'})
feeds.add_feed(add_dict={'lurraldebus_tsst': 'https://www.geo.euskadi.eus/cartografia/DatosDescarga/Transporte/Moveuskadi/ATTG/lurraldebus_tsst/google_transit.zip'})
feeds.add_feed(add_dict={'lurraldebus_zarautz': 'https://www.geo.euskadi.eus/cartografia/DatosDescarga/Transporte/Moveuskadi/ATTG/lurraldebus_zarautz/google_transit.zip'})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-8e04fd56f169> in <cell line: 3>()
#       1 # I manually add all the feeds from the bus transit companies of Gipuzkoa
#       2
# ----> 3 feeds.add_feed(add_dict={'dbus': 'https://www.geo.euskadi.eus/cartografia/DatosDescarga/Transporte/Moveuskadi/ATTG/dbus/google_transit.zip'})
#       4 feeds.add_feed(add_dict={'lurraldebus_areizaga': 'https://www.geo.euskadi.eus/cartografia/DatosDescarga/Transporte/Moveuskadi/ATTG/lurraldebus_areizaga/google_transit.zip'})
#       5 feeds.add_feed(add_dict={'lurraldebus_arrasate': 'https://www.geo.euskadi.eus/cartografia/DatosDescarga/Transporte/Moveuskadi/ATTG/lurraldebus_arrasate/google_transit.zip'})
#
# /usr/local/lib/python3.10/dist-packages/urbanaccess/gtfsfeeds.py in add_feed(self, add_dict, replace)
#     127             for key in add_dict.keys():
#     128                 if key in self.gtfs_feeds.keys():
# --> 129                     raise ValueError(
#     130                         '{} passed in add_dict already exists in gtfs_feeds. '
#     131                         'Only unique keys are allowed to be added.'.format(
#
# ValueError: dbus passed in add_dict already exists in gtfs_feeds. Only unique keys are allowed to be added.

# %%
# I download all these feeds, 40sg
gtfsfeeds.download()
# Out:
# INFO:urbanaccess:19 GTFS feed(s) will be downloaded here: data/gtfsfeed_zips
# 19 GTFS feed(s) will be downloaded here: data/gtfsfeed_zips
# INFO:urbanaccess:dbus GTFS feed downloaded successfully. Took 4.29 seconds for 4,162,404.0KB
# dbus GTFS feed downloaded successfully. Took 4.29 seconds for 4,162,404.0KB
# INFO:urbanaccess:lurraldebus_areizaga GTFS feed downloaded successfully. Took 1.59 seconds for 175,056.0KB
# lurraldebus_areizaga GTFS feed downloaded successfully. Took 1.59 seconds for 175,056.0KB
# INFO:urbanaccess:lurraldebus_arrasate GTFS feed downloaded successfully. Took 1.20 seconds for 56,477.0KB
# lurraldebus_arrasate GTFS feed downloaded successfully. Took 1.20 seconds for 56,477.0KB
# INFO:urbanaccess:lurraldebus_auif_urb GTFS feed downloaded successfully. Took 1.15 seconds for 177.0KB
# lurraldebus_auif_urb GTFS feed downloaded successfully. Took 1.15 seconds for 177.0KB
# INFO:urbanaccess:lurraldebus_eibar GTFS feed downloaded successfully. Took 1.28 seconds for 61,236.0KB
# lurraldebus_eibar GTFS feed downloaded successfully. Took 1.28 seconds for 61,236.0KB
# INFO:urbanaccess:lurraldebus_ekialdebus GTFS feed downloaded successfully. Took 2.61 seconds for 1,498,262.0KB
# lurraldebus_ekialdebus GTFS feed downloaded successfully. Took 2.61 seconds for 1,498,262.0KB
# INFO:urbanaccess:lurraldebus_euskotren_bus GTFS feed downloaded successfully. Took 1.17 seconds for 250.0KB
# lurraldebus_euskotren_bus GTFS feed downloaded successfully. Took 1.17 seconds for 250.0KB
# INFO:urbanaccess:lurraldebus_garayar GTFS feed downloaded successfully. Took 1.66 seconds for 398,196.0KB
# lurraldebus_garayar GTFS feed downloaded successfully. Took 1.66 seconds for 398,196.0KB
# INFO:urbanaccess:lurraldebus_gipuzkoana GTFS feed downloaded successfully. Took 2.16 seconds for 960,175.0KB
# lurraldebus_gipuzkoana GTFS feed downloaded successfully. Took 2.16 seconds for 960,175.0KB
# INFO:urbanaccess:lurraldebus_goierrialdea GTFS feed downloaded successfully. Took 2.45 seconds for 1,153,295.0KB
# lurraldebus_goierrialdea GTFS feed downloaded successfully. Took 2.45 seconds for 1,153,295.0KB
# INFO:urbanaccess:lurraldebus_hernani GTFS feed downloaded successfully. Took 1.18 seconds for 44,208.0KB
# lurraldebus_hernani GTFS feed downloaded successfully. Took 1.18 seconds for 44,208.0KB
# INFO:urbanaccess:lurraldebus_lasarte GTFS feed downloaded successfully. Took 1.19 seconds for 27,179.0KB
# lurraldebus_lasarte GTFS feed downloaded successfully. Took 1.19 seconds for 27,179.0KB
# INFO:urbanaccess:lurraldebus_oiartzun GTFS feed downloaded successfully. Took 1.07 seconds for 12,611.0KB
# lurraldebus_oiartzun GTFS feed downloaded successfully. Took 1.07 seconds for 12,611.0KB
# INFO:urbanaccess:lurraldebus_pesa GTFS feed downloaded successfully. Took 0.98 seconds for 0.0KB
# lurraldebus_pesa GTFS feed downloaded successfully. Took 0.98 seconds for 0.0KB
# INFO:urbanaccess:lurraldebus_renteria GTFS feed downloaded successfully. Took 1.45 seconds for 121,102.0KB
# lurraldebus_renteria GTFS feed downloaded successfully. Took 1.45 seconds for 121,102.0KB
# INFO:urbanaccess:lurraldebus_tbh GTFS feed downloaded successfully. Took 2.35 seconds for 1,054,719.0KB
# lurraldebus_tbh GTFS feed downloaded successfully. Took 2.35 seconds for 1,054,719.0KB
# INFO:urbanaccess:lurraldebus_tolosaldea GTFS feed downloaded successfully. Took 1.90 seconds for 587,957.0KB
# lurraldebus_tolosaldea GTFS feed downloaded successfully. Took 1.90 seconds for 587,957.0KB
# INFO:urbanaccess:lurraldebus_tsst GTFS feed downloaded successfully. Took 1.94 seconds for 691,633.0KB
# lurraldebus_tsst GTFS feed downloaded successfully. Took 1.94 seconds for 691,633.0KB
# INFO:urbanaccess:lurraldebus_zarautz GTFS feed downloaded successfully. Took 1.29 seconds for 97,201.0KB
# INFO:urbanaccess:GTFS feed download completed. Took 32.97 seconds
# lurraldebus_zarautz GTFS feed downloaded successfully. Took 1.29 seconds for 97,201.0KB
# GTFS feed download completed. Took 32.97 seconds
# ---------------------------------------------------------------------------
# BadZipFile                                Traceback (most recent call last)
# <ipython-input-23-2e353c133ad0> in <cell line: 2>()
#       1 # I download all these feeds, 40sg
# ----> 2 gtfsfeeds.download()
#
# /usr/local/lib/python3.10/dist-packages/urbanaccess/gtfsfeeds.py in download(data_folder, feed_name, feed_url, feed_dict, error_pause_duration, delete_zips)
#     541         time.time() - start_time1))
#     542
# --> 543     _unzip(zip_rootpath=download_folder, delete_zips=delete_zips)
#     544
#     545
#
# /usr/local/lib/python3.10/dist-packages/urbanaccess/gtfsfeeds.py in _unzip(zip_rootpath, delete_zips)
#     578     for zfile in zipfilelist:
#     579
# --> 580         with zipfile.ZipFile(os.path.join(zip_rootpath, zfile)) as z:
#     581             # required to deal with zipfiles that have subdirectories and
#     582             # that were created on OSX
#
# /usr/lib/python3.10/zipfile.py in __init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps)
#    1267         try:
#    1268             if mode == 'r':
# -> 1269                 self._RealGetContents()
#    1270             elif mode in ('w', 'x'):
#    1271                 # set the modified flag so central directory gets written
#
# /usr/lib/python3.10/zipfile.py in _RealGetContents(self)
#    1334             raise BadZipFile("File is not a zip file")
#    1335         if not endrec:
# -> 1336             raise BadZipFile("File is not a zip file")
#    1337         if self.debug > 1:
#    1338             print(endrec)
#
# BadZipFile: File is not a zip file

# %% [markdown]
# Let's specify a bounding box of coordinates for Gipuzkoa to subset the GTFS data to. You can generate a bounding box by going to http://boundingbox.klokantech.com/ and selecting the CSV format.

# %%
# Load GTFS data into an UrbanAcess transit data object
# trips = pd.read_csv('/content/drive/MyDrive/CS Gipuzkoa/Data/Gipuzkoa_no_NaNs.csv')
validation = True
verbose = True
# bbox for Gipuzkoa
Lat_min = 42.904155
Long_min = -2.621987
Lat_max = 43.403070
Long_max = -1.740334
bbox = (Long_min,Lat_min,Long_max,Lat_max,)
remove_stops_outsidebbox = True
append_definitions = True

loaded_feeds = ua.gtfs.load.gtfsfeed_to_df(gtfsfeed_path=None,
                                           validation=validation,
                                           verbose=verbose,
                                           bbox=bbox,
                                           remove_stops_outsidebbox=remove_stops_outsidebbox,
                                           append_definitions=append_definitions)
# Out:
# INFO:urbanaccess:Checking GTFS text file header whitespace... Reading files using encoding: utf-8 set in configuration.
# Checking GTFS text file header whitespace... Reading files using encoding: utf-8 set in configuration.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-d7e77a605f17> in <cell line: 14>()
#      12 append_definitions = True
#      13
# ---> 14 loaded_feeds = ua.gtfs.load.gtfsfeed_to_df(gtfsfeed_path=None,
#      15                                            validation=validation,
#      16                                            verbose=verbose,
#
# /usr/local/lib/python3.10/dist-packages/urbanaccess/gtfs/load.py in gtfsfeed_to_df(gtfsfeed_path, validation, verbose, bbox, remove_stops_outsidebbox, append_definitions)
#     245                 'must be specified for validation.')
#     246
# --> 247     _standardize_txt(csv_rootpath=gtfsfeed_path)
#     248
#     249     folderlist = [foldername for foldername in os.listdir(gtfsfeed_path) if
#
# /usr/local/lib/python3.10/dist-packages/urbanaccess/gtfs/load.py in _standardize_txt(csv_rootpath)
#      36     if six.PY2:
#      37         _txt_encoder_check(gtfsfiles_to_use, csv_rootpath)
# ---> 38     _txt_header_whitespace_check(gtfsfiles_to_use, csv_rootpath)
#      39
#      40
#
# /usr/local/lib/python3.10/dist-packages/urbanaccess/gtfs/load.py in _txt_header_whitespace_check(gtfsfiles_to_use, csv_rootpath)
#     129     for folder in folderlist:
#     130         textfilelist = [textfilename for textfilename in
# --> 131                         os.listdir(os.path.join(csv_rootpath, folder)) if
#     132                         textfilename.endswith(".txt")]
#     133
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/gtfsfeed_text/data/gtfsfeed_text'

# %% [markdown]
# # Variables

# %%
timerange = ['05:00:00', '06:00:00']
nombre_archivo = 'transit_0506_pruebas.h5'  # Cambiar el nombre del archivo

# %% [markdown]
# # Create a transit network

# %%
ua.gtfs.network.create_transit_net(gtfsfeeds_dfs=loaded_feeds,
                                   day='monday',
                                   timerange=timerange,
                                   calendar_dates_lookup=None)

# I call the network urbanaccess_net

urbanaccess_net = ua.network.ua_network

#urbanaccess_net.transit_edges.head(25)
#urbanaccess_net.transit_nodes.head(25)
# urbanaccess_net.transit_nodes.plot(kind='scatter', x='x', y='y', s=0.1)

# %% [markdown]
# # Create a pedestrian network

# %%
nodes, edges = ua.osm.load.ua_network_from_bbox(bbox=bbox,
                                                remove_lcn=True)
# Create the network itself

ua.osm.network.create_osm_net(osm_edges=edges,
                              osm_nodes=nodes,
                              travel_speed_mph=3)

# %% [markdown]
# # Create an integrated transit and pedestrian network

# %%
ua.network.integrate_network(urbanaccess_network=urbanaccess_net,
                             headways=False)

# %% [markdown]
# # Add average headways to network travel time

# %% [markdown]
# The network we have generated so far only contains pure travel times. UrbanAccess allows for the calculation of and addition of route stop level average headways to the network. This is used as a proxy for passenger wait times at stops and stations. The route stop level average headway are added to the pedestrian to transit connector edges.
#
# Let's calculate headways for the same AM Peak time period. Statistics on route stop level headways will be added to your GTFS transit data object inside of headways

# %%
ua.gtfs.headways.headways(gtfsfeeds_df=loaded_feeds,
                          headway_timerange=timerange)
loaded_feeds.headways

ua.network.integrate_network(urbanaccess_network=urbanaccess_net,
                             headways=True,
                             urbanaccess_gtfsfeeds_df=loaded_feeds,
                             headway_statistic='mean')

# %% [markdown]
# # Create and save

# %%
s_time = time.time()
transit_ped_net = pdna.network.Network(urbanaccess_net.net_nodes["x"],
                               urbanaccess_net.net_nodes["y"],
                               urbanaccess_net.net_edges["from_int"],
                               urbanaccess_net.net_edges["to_int"],
                               urbanaccess_net.net_edges[["weight"]],
                               twoway=False)
print('Took {:,.2f} seconds'.format(time.time() - s_time))

# %%
transit_ped_net.save_hdf5(f'/content/drive/MyDrive/Mode-choice/CS_NTT_Gipuzkoa/notebooks/transit_24/{nombre_archivo}')

# %%
edgecolor = ua.plot.col_colors(df=urbanaccess_net.net_edges, col='weight', cmap='gist_heat_r', num_bins=5)

ua.plot.plot_net(nodes=urbanaccess_net.net_nodes,
                 edges=urbanaccess_net.net_edges[urbanaccess_net.net_edges['net_type']=='transit'],
                 bbox=bbox,
                 fig_height=30, margin=0.02,
                 edge_color=edgecolor, edge_linewidth=1, edge_alpha=1,
                 node_color='black', node_size=0, node_alpha=1, node_edgecolor='none', node_zorder=3, nodes_only=False)

# %% [markdown]
# # Dibujar

# %%
# urbanaccess_net = ua.network.load_network(filename='final_net.h5')
urbanaccess_net = load_network(dir='/content/drive/MyDrive/Mode-choice/CS_NTT_Gipuzkoa/notebooks/transit_24', filename='transit_0506.h5')
# urbanaccess_net = tr_0506
# Out:
# INFO:urbanaccess:Successfully read store: /content/drive/MyDrive/Mode-choice/CS_NTT_Gipuzkoa/notebooks/transit_24/transit_0506.h5 with the following keys: ['/edges', '/impedance_names', '/nodes', '/two_way']
# INFO:urbanaccess:Successfully read store: /content/drive/MyDrive/Mode-choice/CS_NTT_Gipuzkoa/notebooks/transit_24/transit_0506.h5 with the following keys: ['/edges', '/impedance_names', '/nodes', '/two_way']
# Successfully read store: /content/drive/MyDrive/Mode-choice/CS_NTT_Gipuzkoa/notebooks/transit_24/transit_0506.h5 with the following keys: ['/edges', '/impedance_names', '/nodes', '/two_way']
# Successfully read store: /content/drive/MyDrive/Mode-choice/CS_NTT_Gipuzkoa/notebooks/transit_24/transit_0506.h5 with the following keys: ['/edges', '/impedance_names', '/nodes', '/two_way']

# %%
edgecolor = ua.plot.col_colors(df=urbanaccess_net.net_edges, col='weight', cmap='gist_heat_r', num_bins=5)

ua.plot.plot_net(nodes=urbanaccess_net.net_nodes,
                #  edges=urbanaccess_net.net_edges[urbanaccess_net.net_edges['net_type']=='transit'],
                 edges=urbanaccess_net.net_edges,
                 bbox=bbox,
                 fig_height=30, margin=0.02,
                 edge_color=edgecolor, edge_linewidth=1, edge_alpha=1,
                 node_color='black', node_size=0, node_alpha=1, node_edgecolor='none', node_zorder=3, nodes_only=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: None
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-bf07fb135a70> in <cell line: 3>()
#       1 edgecolor = ua.plot.col_colors(df=urbanaccess_net.net_edges, col='weight', cmap='gist_heat_r', num_bins=5)
#       2
# ----> 3 ua.plot.plot_net(nodes=urbanaccess_net.net_nodes,
#       4                 #  edges=urbanaccess_net.net_edges[urbanaccess_net.net_edges['net_type']=='transit'],
#       5                  edges=urbanaccess_net.net_edges,
#
# /usr/local/lib/python3.10/dist-packages/urbanaccess/plot.py in plot_net(nodes, edges, x_col, y_col, from_col, to_col, bbox, fig_height, margin, edge_color, edge_linewidth, edge_alpha, node_color, node_size, node_alpha, node_edgecolor, node_zorder, nodes_only, ax)
#      91
#      92     # if edge df is subset make sure nodes are also subset to match
# ---> 93     from_ids = nodes[nodes.index.isin(list(edges[from_col]))]
#      94     to_id = nodes[nodes.index.isin(list(edges[to_col]))]
#      95     node_ids = pd.concat([from_ids, to_id], ignore_index=False)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3805             if self.columns.nlevels > 1:
#    3806                 return self._getitem_multilevel(key)
# -> 3807             indexer = self.columns.get_loc(key)
#    3808             if is_integer(indexer):
#    3809                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
# -> 3804                 raise KeyError(key) from err
#    3805             except TypeError:
#    3806                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: None

# %%
import h5py
import folium

# Cargar el archivo .h5 que contiene datos geoespaciales
# Asegúrate de que el archivo .h5 contenga datos geoespaciales en un formato específico
with h5py.File('/content/drive/MyDrive/Mode-choice/CS_NTT_Gipuzkoa/notebooks/transit_24/transit_0506.h5', 'r') as f:
    # Supongamos que los datos geoespaciales están almacenados en un dataset llamado 'coordenadas'
    coordenadas = f['coordenadas'][:]

# Crear un mapa de Folium
mapa = folium.Map(location=[x, y], zoom_start=10)

# Agregar marcadores o líneas al mapa según los datos geoespaciales
for coord in coordenadas:
    lat, lon = coord[0], coord[1]
    folium.Marker(location=[lat, lon]).add_to(mapa)

# Guardar el mapa interactivo en un archivo HTML
mapa.save('mapa_de_carreteras.html')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-4276006facf5> in <cell line: 6>()
#       6 with h5py.File('/content/drive/MyDrive/Mode-choice/CS_NTT_Gipuzkoa/notebooks/transit_24/transit_0506.h5', 'r') as f:
#       7     # Supongamos que los datos geoespaciales están almacenados en un dataset llamado 'coordenadas'
# ----> 8     coordenadas = f['coordenadas'][:]
#       9
#      10 # Crear un mapa de Folium
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# /usr/local/lib/python3.10/dist-packages/h5py/_hl/group.py in __getitem__(self, name)
#     355                 raise ValueError("Invalid HDF5 object reference")
#     356         elif isinstance(name, (bytes, str)):
# --> 357             oid = h5o.open(self.id, self._e(name), lapl=self._lapl)
#     358         else:
#     359             raise TypeError("Accessing a group is done with bytes or str, "
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/h5o.pyx in h5py.h5o.open()
#
# KeyError: "Unable to open object (object 'coordenadas' doesn't exist)"
