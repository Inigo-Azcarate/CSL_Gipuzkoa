# %%
import pickle
import os
import pandas as pd
import pandana as pdn
import numpy as np

# %%
model_name = "RandomForestClassifier"  # El nombre del modelo que guardaste anteriormente
file_path = os.path.join("models", f'{model_name}.pkl')

with open(file_path, 'rb') as file:
    model = pickle.load(file)

# %%
Per_hog = 1
Turismos = 2
Edad = 4
crnt_tur = 1
Tipo_familia = 1

# Trip 1: Aldapeta-Eskuzaitzeta

Hora_Ini_1 = 109
# Aldapeta
O_long_1 = -1.987629
O_lat_1 = 43.314393
# Eskuzaitzeta
D_long_1 = -2.032227 
D_lat_1 =43.254493
Com_Ori = 'Donostialdea'
Com_Des = 'Donostialdea'
Mun_Ori = 'Donostia/San Sebastian'
Mun_Des = 'Donostia/San Sebastian'
drive_tt_1 = 9.219617
pt_tt_1 = 35.678
drive_tc_1 = 16580.6871
pt_tc_1 = 0.851818
distance_1 = 9085.308

trips_1 = pd.DataFrame(columns=['Hora_Ini', 'Per_hog', 'Turismos', 'Edad', 'crnt_tur','drive_tt','pt_tt','drive_tc','pt_tc','distance','Tipo_familia'])
fila = pd.Series({'Hora_Ini': Hora_Ini_1, 'Per_hog': Per_hog, 'Turismos': Turismos, 'Edad': Edad, 'crnt_tur': crnt_tur,'drive_tt': drive_tt_1,'pt_tt': pt_tt_1,'drive_tc': drive_tc_1,'pt_tc': pt_tc_1,'distance': distance_1, 'Tipo_familia': Tipo_familia})
trips_1 = pd.concat([trips_1, pd.DataFrame([fila])], ignore_index=True)
trips_1

x = np.array(trips_1)
y_pred = model.predict(x)
y_pred

import matplotlib.pyplot as plt

# Contar la frecuencia de cada tipo de valor
from collections import Counter
value_counts = Counter(y_pred)

# Extraer las etiquetas y sus frecuencias
labels, counts = zip(*value_counts.items())

# Crear un gráfico de pastel
plt.pie(counts, labels=labels, autopct='%1.1f%%', startangle=140)
plt.axis('equal')  # Para asegurarse de que el gráfico de pastel sea circular

# Mostrar el gráfico
plt.show()

# %%
# Trip 2

Per_hog = 1
Turismos = 1
Edad = 5
crnt_tur = 1
Tipo_familia = 3

Hora_Ini_2 = 109
# Beasain
O_long_2 = -1.987629
O_lat_2 = 43.314393
# Tolosa
D_long_2 = -2.075877 
D_lat_2 = 43.134683
Com_Ori = 'Goierri'
Com_Des = 'Tolosaldea'
Mun_Ori = 'Beasain'
Mun_Des = 'Tolosa'

drive_tt_2 = 10.234167
pt_tt_2 = 33.66
drive_tc_2 = 27812.388625
# drive_tc_2 = 60000
pt_tc_2 = 0.998864
# pt_tc_2 = 0.1
distance_2 = 15239.665
# distance_2 = 10000

trips_2 = pd.DataFrame(columns=['Hora_Ini', 'Per_hog', 'Turismos', 'Edad', 'crnt_tur','drive_tt','pt_tt','drive_tc','pt_tc','distance','Tipo_familia'])
fila = pd.Series({'Hora_Ini': Hora_Ini_2, 'Per_hog': Per_hog, 'Turismos': Turismos, 'Edad': Edad, 'crnt_tur': crnt_tur,'drive_tt': drive_tt_2,'pt_tt': pt_tt_2,'drive_tc': drive_tc_2,'pt_tc': pt_tc_2,'distance': distance_2, 'Tipo_familia': Tipo_familia})
trips_2 = pd.concat([trips_2, pd.DataFrame([fila])], ignore_index=True)
trips_2

x = np.array(trips_2)
y_pred = model.predict(x)
y_pred

import matplotlib.pyplot as plt

# Contar la frecuencia de cada tipo de valor
from collections import Counter
value_counts = Counter(y_pred)

# Extraer las etiquetas y sus frecuencias
labels, counts = zip(*value_counts.items())

# Crear un gráfico de pastel
plt.pie(counts, labels=labels, autopct='%1.1f%%', startangle=140)
plt.axis('equal')  # Para asegurarse de que el gráfico de pastel sea circular

# Mostrar el gráfico
plt.show()

# %%
# Trip 3

Per_hog = 3
Turismos = 3
Edad = 4
crnt_tur = 1
Tipo_familia = 4

Hora_Ini_3 = 109
# Bergara 43.116649, -2.415406
O_long_3 = -2.415406
O_lat_3 = 43.116649
# Zarautz 43.277973, -2.173639
D_long_3 = -2.173639 
D_lat_3 = 43.277973
Com_Ori = 'Debagoiena'
Com_Des = 'Urola Kosta'
Mun_Ori = 'Bergara'
Mun_Des = 'Zarautz'
drive_tt_3 = 26.1228
pt_tt_3 = 43.765
drive_tc_3 = 64859.7043	
pt_tc_3 = 2.352727
distance_3 = 35539.564

trips_3 = pd.DataFrame(columns=['Hora_Ini', 'Per_hog', 'Turismos', 'Edad', 'crnt_tur','drive_tt','pt_tt','drive_tc','pt_tc','distance','Tipo_familia'])
fila = pd.Series({'Hora_Ini': Hora_Ini_2, 'Per_hog': Per_hog, 'Turismos': Turismos, 'Edad': Edad, 'crnt_tur': crnt_tur,'drive_tt': drive_tt_2,'pt_tt': pt_tt_2,'drive_tc': drive_tc_2,'pt_tc': pt_tc_2,'distance': distance_2, 'Tipo_familia': Tipo_familia})
trips_3 = pd.concat([trips_3, pd.DataFrame([fila])], ignore_index=True)
trips_3

x = np.array(trips_3)
y_pred = model.predict(x)
y_pred

import matplotlib.pyplot as plt

# Contar la frecuencia de cada tipo de valor
from collections import Counter
value_counts = Counter(y_pred)

# Extraer las etiquetas y sus frecuencias
labels, counts = zip(*value_counts.items())

# Crear un gráfico de pastel
plt.pie(counts, labels=labels, autopct='%1.1f%%', startangle=140)
plt.axis('equal')  # Para asegurarse de que el gráfico de pastel sea circular

# Mostrar el gráfico
plt.show()

# %%
trips_demo = pd.DataFrame(columns=['Com_Ori', 'Com_Des', 'Mun_Ori', 'Mun_Des','Hora_Ini', 'Per_hog', 'Turismos', 'Edad', 'crnt_tur', 'Tipo_familia', 'O_long', 'O_lat', 'D_long', 'D_lat'])
trips_demo

Hora_Ini = 109
O_long = -2.415406
O_lat = 43.116649
# Tolosa
D_long = -2.173639 
D_lat = 43.277973
Com_Ori = 'Debagoiena'
Com_Des = 'Urola Kosta'
Mun_Ori = 'Bergara'
Mun_Des = 'Zarautz'

fila = pd.Series({'Com_Ori': Com_Ori,'Com_Des': Com_Des,'Mun_Ori': Mun_Ori,'Mun_Des': Mun_Des,'Hora_Ini': Hora_Ini, 'Per_hog': Per_hog, 'Turismos': Turismos, 'Edad': Edad, 'crnt_tur': crnt_tur, 'Tipo_familia': Tipo_familia, 'O_long': O_long, 'O_lat': O_lat, 'D_long': D_long, 'D_lat': D_lat})
# trips_demo = trips_demo.append(fila, ignore_index=True)
trips_demo = pd.concat([trips_demo, pd.DataFrame([fila])], ignore_index=True)
trips_demo
# Out:
#       Com_Ori      Com_Des  Mun_Ori  Mun_Des Hora_Ini Per_hog Turismos Edad  \
# 0  Debagoiena  Urola Kosta  Bergara  Zarautz      109       1        1    5
#
#   crnt_tur Tipo_familia    O_long      O_lat    D_long      D_lat
# 0        1            3 -2.415406  43.116649 -2.173639  43.277973

# %% [markdown]
# # Function

# %%
# Datos

Hora_Ini = 109

# Trip 1: Aldapeta-Eskuzaitzeta
Hora_Ini_1 = Hora_Ini

drive_tt_1 = 9.219617
pt_tt_1 = 35.678
drive_tc_1 = 16580.6871
pt_tc_1 = 0.851818
distance_1 = 9085.308

# Trip 2: Beasain-Tolosa
Hora_Ini_2 = Hora_Ini

drive_tt_2 = 10.234167
pt_tt_2 = 33.66
drive_tc_2 = 27812.388625
# drive_tc_2 = 60000
pt_tc_2 = 0.998864
# pt_tc_2 = 0.1
distance_2 = 15239.665
# distance_2 = 10000

# Trip 3: Bergara-Zarautz
Hora_Ini_3 = Hora_Ini

drive_tt_3 = 26.1228
pt_tt_3 = 43.765
drive_tc_3 = 64859.7043	
pt_tc_3 = 2.352727
distance_3 = 35539.564

trips_demo = pd.DataFrame(columns=['Hora_Ini', 'Per_hog', 'Turismos', 'Edad', 'crnt_tur','drive_tt','pt_tt','drive_tc','pt_tc','distance','Tipo_familia'])
fila1 = pd.Series({'Hora_Ini': Hora_Ini_1, 'Per_hog': 0, 'Turismos': 0, 'Edad': 0, 'crnt_tur': 0,'drive_tt': drive_tt_1,'pt_tt': pt_tt_1,'drive_tc': drive_tc_1,'pt_tc': pt_tc_1,'distance': distance_1, 'Tipo_familia': 0})
fila2 = pd.Series({'Hora_Ini': Hora_Ini_2, 'Per_hog': 0, 'Turismos': 0, 'Edad': 0, 'crnt_tur': 0,'drive_tt': drive_tt_2,'pt_tt': pt_tt_2,'drive_tc': drive_tc_2,'pt_tc': pt_tc_2,'distance': distance_2, 'Tipo_familia': 0})
fila3 = pd.Series({'Hora_Ini': Hora_Ini_3, 'Per_hog': 0, 'Turismos': 0, 'Edad': 0, 'crnt_tur': 0,'drive_tt': drive_tt_3,'pt_tt': pt_tt_3,'drive_tc': drive_tc_3,'pt_tc': pt_tc_3,'distance': distance_3, 'Tipo_familia': 0})
trips_demo = pd.concat([trips_demo, pd.DataFrame([fila1]), pd.DataFrame([fila2]), pd.DataFrame([fila3])], ignore_index=True)
trips_demo
# Out:
#    Hora_Ini  Per_hog  Turismos  Edad  crnt_tur   drive_tt   pt_tt  \
# 0     109.0      0.0       0.0   0.0       0.0   9.219617  35.678
# 1     109.0      0.0       0.0   0.0       0.0  10.234167  33.660
# 2     109.0      0.0       0.0   0.0       0.0  26.122800  43.765
#
#        drive_tc     pt_tc   distance  Tipo_familia
# 0  16580.687100  0.851818   9085.308           0.0
# 1  27812.388625  0.998864  15239.665           0.0
# 2  64859.704300  2.352727  35539.564           0.0

# %%
def predict_demo(Per_hog, Turismos, Edad, crnt_tur, Tipo_familia, model, trips_demo):
    # trips_demo.at[0, 'Per_hog'] = Per_hog
    # trips_demo.at[0, 'Turismos'] = Turismos
    # trips_demo.at[0, 'Edad'] = Edad
    # trips_demo.at[0, 'crnt_tur'] = crnt_tur
    # trips_demo.at[0, 'Tipo_familia'] = Tipo_familia

    trips_demo = trips_demo.assign(Per_hog = Per_hog)
    trips_demo = trips_demo.assign(Turismos = Turismos)
    trips_demo = trips_demo.assign(Edad = Edad)
    trips_demo = trips_demo.assign(crnt_tur = crnt_tur)
    trips_demo = trips_demo.assign(Tipo_familia = Tipo_familia)
    
    x = np.array(trips_demo)
    y_pred = model.predict(x)
    return y_pred
trips_demo
predict_demo(1,2,3,1,3,model,trips_demo)
# Out:
# array(['Coche', 'Coche', 'Coche'], dtype=object)

# %%
predict_demo(2,1,4,1,3,model,trips_demo)
# Out:
# array(['TP', 'TP', 'Coche'], dtype=object)

# %% [markdown]
# # Categorical variables

# %% [markdown]
# # Añadir el Travel Time

# %%
# Crea un diccionario, donde los valores son None y las claves son esas cuatro

networks = dict.fromkeys({
 "walk",
 "transit",
 "train",
 "drive",
})

# Asigna al valor correspondiente en el diccionario networks un objeto de red creado mediante el método from_hdf5() de la clase Network del módulo pdn.network. 
# Los creados con los codigos anteriores

for k in networks:
    print(k)
    networks[k] = pdn.network.Network.from_hdf5(f'networks/{k}_net.h5')
# Out:
# transit
# drive
# train
# walk

# %%
trips_ez = trips_demo
trips_ez
# Out:
#       Com_Ori      Com_Des  Mun_Ori  Mun_Des Hora_Ini Per_hog Turismos Edad  \
# 0  Debagoiena  Urola Kosta  Bergara  Zarautz      109       1        1    5
#
#   crnt_tur Tipo_familia    O_long      O_lat    D_long      D_lat
# 0        1            3 -2.415406  43.116649 -2.173639  43.277973

# %%
# Asignar tt a cada modo de transporte para cada trip

# Para cada trip, asigna la distancia mas corta que se puede hacer con Network (walk, drive, transit) con shortest_path_lengths
# Coge lat,long de origen y destino de cada trip. A ese origen y destino le asigna el nodo del Network correspondiente más cercano con get_node_ids
# Le pasa esos nodos del Network correspondiente a shortest_path_lengths, y este calcula la distancia entre esos nodos

for k in networks:
    if k != 'drive':
        trips_ez[f"{k}_tt"] = networks[k].shortest_path_lengths(
            networks[k].get_node_ids(trips_ez.O_long,trips_ez.O_lat),
            networks[k].get_node_ids(trips_ez.D_long,trips_ez.D_lat)
            )

trips_ez["walk_tt"] = trips_ez["walk_tt"] / 80.46 # Pasar de distancia (m) a minutos con un ritmo de 3 mp/h = 80.46 m/min.

trips_ez["drive_tt"] = networks['drive'].shortest_path_lengths(
            networks['drive'].get_node_ids(trips_ez.O_long,trips_ez.O_lat),
            networks['drive'].get_node_ids(trips_ez.D_long,trips_ez.D_lat),
            imp_name='drive_time_s'
            )

trips_ez["distance"] = networks['drive'].shortest_path_lengths(
            networks['drive'].get_node_ids(trips_ez.O_long,trips_ez.O_lat),
            networks['drive'].get_node_ids(trips_ez.D_long,trips_ez.D_lat),
            imp_name='distance'
            )

trips_ez["drive_tt"] = trips_ez["drive_tt"] / 60 # Para pasar a minutos
trips_ez["bike_tt"] =  networks['drive'].shortest_path_lengths(
            networks['drive'].get_node_ids(trips_ez.O_long,trips_ez.O_lat),
            networks['drive'].get_node_ids(trips_ez.D_long,trips_ez.D_lat),
            imp_name='distance'
            )
trips_ez["bike_tt"] = trips_ez["bike_tt"] * 60 / (1000*13.07)  # 13.07 km/h = 13.07*1000/60 m/min

# trips_ez['pt_tt'] = trips_ez[['train_tt', 'transit_tt']].min(axis=1)
# trips_ez = trips_ez.drop(columns=['train_tt', 'transit_tt'])

# Eliminar andando y bike

trips_ez = trips_ez.drop(columns=['walk_tt', 'bike_tt'])
trips_ez
# Out:
#       Com_Ori      Com_Des  Mun_Ori  Mun_Des Hora_Ini Per_hog Turismos Edad  \
# 0  Debagoiena  Urola Kosta  Bergara  Zarautz      109       1        1    5
#
#   crnt_tur Tipo_familia    O_long      O_lat    D_long      D_lat  transit_tt  \
# 0        1            3 -2.415406  43.116649 -2.173639  43.277973      43.765
#
#    train_tt  drive_tt   distance
# 0   220.964   26.1228  35539.564

# %% [markdown]
# # Añadir Travel Cost

# %%
# Coche, precio por km

fuel_price_11=1.328 #€/litro
fuel_price_16=1.151 #€/litro
fuel_price_21=1.825 #€/litro
consumo_medio=7 #litros/100km
precio_21=(fuel_price_21*consumo_medio/100)/1000
precio_16=(fuel_price_16*consumo_medio/100)/1000
precio_11=(fuel_price_11*consumo_medio/100)/1000

def custom_multiplier(row):
    if row['Año'] == 2021:
        return row['distance'] * precio_21
    elif row['Año'] == 2016:
        return row['distance'] * precio_16
    else:
        return row['distance'] * precio_11

# trips_train['drive_tc'] = trips_train.apply(custom_multiplier, axis=1)
trips_ez['drive_tc'] = trips_ez['distance']*fuel_price_21

# %%
precio_21=(fuel_price_21*consumo_medio/100)/1000
precio_21
# Out:
# 0.00012775000000000002

# %%
# Transporte publico

#Precios

precios_lurraldebus = pd.read_excel(f"data/saltos_precio_tp_gipuzkoa.xlsx", sheet_name='Lurraldebus_precios', usecols=[0, 1])
precios_euskotren = pd.read_excel(f"data/saltos_precio_tp_gipuzkoa.xlsx", sheet_name='Euskotren_precios', usecols=[0, 1])
precios_renfe = pd.read_excel(f"data/saltos_precio_tp_gipuzkoa.xlsx", sheet_name='Renfe_precios', usecols=[0, 1])

precios_lurraldebus=precios_lurraldebus.dropna()
precios_euskotren=precios_euskotren.dropna()
precios_renfe=precios_renfe.dropna()

# Saltos entre comarcas

saltos_lurraldebus = pd.read_csv(f"data/saltos_lurraldebus.csv")
saltos_euskotren = pd.read_csv(f"data/saltos_euskotren.csv")
saltos_renfe = pd.read_csv(f"data/saltos_renfe.csv")

saltos_lurraldebus=saltos_lurraldebus.merge(precios_lurraldebus, on='Saltos', how='left')
saltos_euskotren=saltos_euskotren.merge(precios_euskotren, on='Saltos', how='left')
saltos_renfe=saltos_renfe.merge(precios_renfe, on='Saltos', how='left')

saltos_lurraldebus.rename(columns={'COMARCA ORI': 'Com_Ori'}, inplace=True)
saltos_lurraldebus.rename(columns={'COMARCA DES': 'Com_Des'}, inplace=True)

saltos_euskotren.rename(columns={'Poblacion ORIGEN': 'Mun_Ori'}, inplace=True)
saltos_euskotren.rename(columns={'Poblacion DESTINO': 'Mun_Des'}, inplace=True)

saltos_renfe.rename(columns={'Poblacion ORIGEN': 'Mun_Ori'}, inplace=True)
saltos_renfe.rename(columns={'Poblacion DESTINO': 'Mun_Des'}, inplace=True)

# %%
# Asignar precio TP

# Para el caso del bus, todos tienen un precio aunque no estén conectados, porque el precio va por comarcas. La opción se verá penalizada por el transit_weight si no están conectados directamente. Su valor será muy elevado.

trips_ez = trips_ez.merge(saltos_lurraldebus, on=["Com_Ori", "Com_Des"], how="left")
trips_ez.rename(columns={'Saltos': 'Saltos_lurraldebus'}, inplace=True)
trips_ez.rename(columns={'Precio': 'Precio_lurraldebus'}, inplace=True)

# Para el caso del tren la granuralidad es mejor porque va por pueblos, por lo que si da un valor bien, y si devuelve NaN lo vamos a sustituir por un 0. O un infinito??
# ??????????

trips_ez = trips_ez.merge(saltos_euskotren, on=["Mun_Ori", "Mun_Des"], how="left")
trips_ez.rename(columns={'Saltos': 'Saltos_euskotren'}, inplace=True)
trips_ez.rename(columns={'Precio': 'Precio_euskotren'}, inplace=True)

trips_ez = trips_ez.merge(saltos_renfe, on=["Mun_Ori", "Mun_Des"], how="left")
trips_ez.rename(columns={'Saltos': 'Saltos_renfe'}, inplace=True)
trips_ez.rename(columns={'Precio': 'Precio_renfe'}, inplace=True)

# Eliminar las columnas de saltos que no aportan nada

trips_ez=trips_ez.drop(columns=['Saltos_lurraldebus','Saltos_euskotren','Saltos_renfe'])

# Sustituir los NaN por 0. Bien o por infinito mejor? En verdad quizá da igual, porque si tiene NaN es que no están conectados por tren, por lo que train_weight será MUY grande y lo penalizará.
trips_ez = trips_ez.fillna(0)

# trips['Precio_euskotren'] = trips['Precio_euskotren'].astype(float)
# trips['Precio_renfe'] = trips['Precio_renfe'].astype(float)

# Combinar columnas de precios del tren

trips_ez['train_tc'] = np.where((trips_ez['Precio_euskotren'] == 0) & (trips_ez['Precio_renfe'] == 0), 0,  # Ambas son cero
                           np.where((trips_ez['Precio_euskotren'] != 0) & (trips_ez['Precio_renfe'] != 0), (trips_ez['Precio_euskotren'] + trips_ez['Precio_renfe']) / 2,  # Ninguna es cero
                                    np.maximum(trips_ez['Precio_euskotren'], trips_ez['Precio_renfe'])))  # Una es cero y la otra no

trips_ez.rename(columns={'Precio_lurraldebus': 'transit_tc'}, inplace=True)
trips_ez = trips_ez.drop(columns=['Precio_euskotren','Precio_renfe'])

# Cojo el precio del que va a coger el triptaker, esto es, el que menos tarda

trips_ez['pt_tc'] = trips_ez.apply(lambda row: row['transit_tc'] if row['transit_tt'] < row['train_tt'] else row['train_tc'], axis=1)

# Cojo el tiempo que menos tarda entre transit y train

trips_ez['pt_tt'] = trips_ez[['train_tt', 'transit_tt']].min(axis=1)
trips_ez = trips_ez.drop(columns=['train_tt', 'transit_tt', 'transit_tc', 'train_tc'])

# %%
trips_ez
# Out:
#       Com_Ori      Com_Des  Mun_Ori  Mun_Des  Hora_Ini  Per_hog  Turismos  \
# 0  Debagoiena  Urola Kosta  Bergara  Zarautz       109        1         1
#
#    Edad  crnt_tur  Tipo_familia    O_long      O_lat    D_long      D_lat  \
# 0     5         1             3 -2.415406  43.116649 -2.173639  43.277973
#
#    drive_tt   distance    drive_tc     pt_tc   pt_tt
# 0   26.1228  35539.564  64859.7043  2.352727  43.765
